# %%
)co ../pqty
# Out:
# ...
#    Compiling FriCAS source code from file
#       /home/kfp/Development/physqty/Untitled Folder/../pqty.spad using
#       old system compiler.
#    RIA abbreviates domain RationalInterval
# ------------------------------------------------------------------------
#    initializing NRLIB RIA for RationalInterval
#    compiling into NRLIB RIA
# Adding $ modemaps
# Adding (Fraction (Integer)) modemaps
#    compiling exported mki : (Fraction Integer,Fraction Integer) -> $
# Adding (Boolean) modemaps
# Time: 0.07 SEC.
#
# Adding (Fraction (Integer)) modemaps
#    compiling exported lb : $ -> Fraction Integer
#       RIA;lb;$F;2 is replaced by QCAR
# Time: 0.00 SEC.
#
# Adding (Fraction (Integer)) modemaps
#    compiling exported ub : $ -> Fraction Integer
#       RIA;ub;$F;3 is replaced by QCDR
# Time: 0.00 SEC.
#
#    compiling exported + : ($,$) -> $
# Adding (Fraction (Integer)) modemaps
# Time: 0.00 SEC.
#
#    compiling exported - : ($,$) -> $
# Adding (Fraction (Integer)) modemaps
# ...

# %%
%m(2)
# Out:
#     2
#    m
#                                                                      Type: SI
